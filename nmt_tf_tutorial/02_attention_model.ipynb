# %%
# -*- coding: utf-8 -*-
import numpy as np
import tensorflow as tf
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
TOKEN_PAD="<p>"
TOKEN_START="<s>"
TOKEN_END="</s>"

source_sentences = ["취미가 뭐예요", "만나서 반가워요", "내일 만나서 놀아요"]
target_sentences = ["what is your hobby", "nice to meet you", "meet tomorrow"]

source_vocab = [TOKEN_PAD, TOKEN_START, TOKEN_END, "취미가", "뭐예요", "만나서", "반가워요", "내일", "놀아요"]
target_vocab = [TOKEN_PAD, TOKEN_START, TOKEN_END, "what", "is", "your", "hobby", "nice", "to", "meet", "you", "tomorrow"]

source_input_idx = [
    [3,  4,  0,  0,  0], 
    [5,  6,  0,  0,  0],  
    [7,  5,  8,  0,  0]]
target_input_idx = [
    [1,  3,  4,  5,  6], 
    [1,  7,  8,  9, 10], 
    [1,  9, 11,  0,  0]]
target_output_idx = [
    [3,  4,  5,  6,  2], 
    [7,  8,  9, 10,  2], 
    [9, 11,  2,  0,  0]]
    
source_vocab_size = len(source_vocab)
target_vocab_size = len(target_vocab)

embedding_size = 12
num_units = 12
num_layer = 1

batch_size = 3
learning_rate = 0.0001

training_steps = 40000
display_step = 200

max_sentence_length = 5
                   
source_inputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='source_inputs')
target_inputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='target_inputs')
target_outputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='target_outputs')

def build_single_cell(num_units):
    cell = tf.contrib.rnn.BasicLSTMCell(num_units)
    return cell
                   
with tf.variable_scope('encoder'):
    
    initializer = tf.contrib.layers.xavier_initializer()
    embedding_encoder = tf.get_variable(name="embedding_encoder",
                                        shape=[source_vocab_size, embedding_size], 
                                        dtype=tf.float32,
                                        initializer=initializer,
                                        trainable=True)
    
    encoder_embeddding_inputs = tf.nn.embedding_lookup(params=embedding_encoder,
                                                       ids=source_inputs)

    encoder_cell_list = [build_single_cell(num_units) for i in range(num_layer)]
    encoder_multi_cell = tf.contrib.rnn.MultiRNNCell(encoder_cell_list)
    
    encoder_outputs, encoder_final_state = tf.nn.dynamic_rnn(cell=encoder_multi_cell,
                                                             inputs=encoder_embeddding_inputs,
                                                             dtype=tf.float32)
    
with tf.variable_scope('decoder'):
    
    initializer = tf.contrib.layers.xavier_initializer()
    embedding_decoder = tf.get_variable(name="embedding_decoder",
                                        shape=[target_vocab_size, embedding_size], 
                                        dtype=tf.float32,
                                        initializer=initializer,
                                        trainable=True)
    
    decoder_embeddding_inputs = tf.nn.embedding_lookup(params=embedding_decoder,
                                                       ids=target_inputs)
    
    decoder_cell_list = [build_single_cell(num_units) for i in range(num_layer)]
        
    # Attention mechanism #
    attention_mechanism = tf.contrib.seq2seq.BahdanauAttention(num_units=num_units, 
                                                              memory=encoder_outputs) 
    ######################
    
    # Attention mechanism #
    decoder_cell_list[-1] = tf.contrib.seq2seq.AttentionWrapper(
            cell=decoder_cell_list[-1],
            attention_mechanism=attention_mechanism,
            initial_cell_state=encoder_final_state[-1],
            name='Attention_Wrapper')
    ######################
    
    # Attention mechanism #
    decoder_initial_state = [decoder_cell_list[-1].zero_state(batch_size=batch_size, dtype=tf.float32)]
    decoder_initial_state[0].clone(cell_state=encoder_final_state[-1])
    decoder_initial_state = tuple(decoder_initial_state)
    ######################
    
#     decoder_initial_state = encoder_final_state
    
    decoder_multi_cell = tf.contrib.rnn.MultiRNNCell(decoder_cell_list)
    decoder_outputs, decoder_final_state = tf.nn.dynamic_rnn(cell=decoder_multi_cell,
                                                             inputs=decoder_embeddding_inputs,
                                                             initial_state=decoder_initial_state,
                                                             dtype=tf.float32)

    decoder_predict = tf.argmax(decoder_outputs, 2)
    
with tf.variable_scope("optimizer"):
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=decoder_outputs,
                                                            labels=target_outputs)
    cost = tf.reduce_mean(cross_entropy)
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    optimizer = optimizer.minimize(cost)
    
    correct_pred = tf.equal(tf.argmax(decoder_outputs, 2), target_outputs)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(tf.global_variables_initializer())

    for step in range(1, training_steps + 1):
        batch_source_input = source_input_idx
        batch_target_input = target_input_idx
        batch_target_output = target_output_idx
        
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={source_inputs: batch_source_input, 
                                       target_inputs: batch_target_input,
                                       target_outputs: batch_target_output})
        
        if step % display_step == 0 or step == 1:
            # Calculate batch accuracy & loss
            outputs, acc, loss = sess.run([decoder_predict, accuracy, cost], feed_dict={source_inputs: batch_source_input, 
                                                              target_inputs: batch_target_input,
                                                              target_outputs: batch_target_output})
            
            print("Step " + str(step * batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
            
        if acc >= 1:
            for sentence in outputs:
                sentence = [target_vocab[word_idx] for word_idx in sentence]
                print("           -> ", sentence)
                
            break;

    print("Optimization Finished!")
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={source_inputs: source_input_idx, 
                                                             target_inputs: target_input_idx,
                                                             target_outputs: target_output_idx}))
# Out:
# Step 3, Minibatch Loss= 2.493907, Training Accuracy= 0.06667
# Step 600, Minibatch Loss= 2.468478, Training Accuracy= 0.13333
# Step 1200, Minibatch Loss= 2.431355, Training Accuracy= 0.20000
# Step 1800, Minibatch Loss= 2.358920, Training Accuracy= 0.20000
# Step 2400, Minibatch Loss= 2.238310, Training Accuracy= 0.20000
# Step 3000, Minibatch Loss= 2.126917, Training Accuracy= 0.20000
# Step 3600, Minibatch Loss= 2.050583, Training Accuracy= 0.20000
# Step 4200, Minibatch Loss= 1.997357, Training Accuracy= 0.20000
# Step 4800, Minibatch Loss= 1.952379, Training Accuracy= 0.20000
# Step 5400, Minibatch Loss= 1.910073, Training Accuracy= 0.20000
# Step 6000, Minibatch Loss= 1.874375, Training Accuracy= 0.20000
# Step 6600, Minibatch Loss= 1.847783, Training Accuracy= 0.20000
# Step 7200, Minibatch Loss= 1.828829, Training Accuracy= 0.20000
# Step 7800, Minibatch Loss= 1.815299, Training Accuracy= 0.20000
# Step 8400, Minibatch Loss= 1.805339, Training Accuracy= 0.20000
# Step 9000, Minibatch Loss= 1.797561, Training Accuracy= 0.20000
# Step 9600, Minibatch Loss= 1.790845, Training Accuracy= 0.26667
# Step 10200, Minibatch Loss= 1.783980, Training Accuracy= 0.26667
# Step 10800, Minibatch Loss= 1.775592, Training Accuracy= 0.26667
# Step 11400, Minibatch Loss= 1.762968, Training Accuracy= 0.26667
# Step 12000, Minibatch Loss= 1.748062, Training Accuracy= 0.26667
# Step 12600, Minibatch Loss= 1.734769, Training Accuracy= 0.33333
# Step 13200, Minibatch Loss= 1.722947, Training Accuracy= 0.26667
# Step 13800, Minibatch Loss= 1.713405, Training Accuracy= 0.26667
# Step 14400, Minibatch Loss= 1.705687, Training Accuracy= 0.26667
# Step 15000, Minibatch Loss= 1.698980, Training Accuracy= 0.26667
# Step 15600, Minibatch Loss= 1.691734, Training Accuracy= 0.26667
# Step 16200, Minibatch Loss= 1.683679, Training Accuracy= 0.33333
# Step 16800, Minibatch Loss= 1.675598, Training Accuracy= 0.33333
# Step 17400, Minibatch Loss= 1.668370, Training Accuracy= 0.33333
# Step 18000, Minibatch Loss= 1.662675, Training Accuracy= 0.33333
# Step 18600, Minibatch Loss= 1.658172, Training Accuracy= 0.33333
# Step 19200, Minibatch Loss= 1.654428, Training Accuracy= 0.33333
# Step 19800, Minibatch Loss= 1.651185, Training Accuracy= 0.33333
# Step 20400, Minibatch Loss= 1.648308, Training Accuracy= 0.33333
# Step 21000, Minibatch Loss= 1.645694, Training Accuracy= 0.33333
# Step 21600, Minibatch Loss= 1.643171, Training Accuracy= 0.33333
# Step 22200, Minibatch Loss= 1.640416, Training Accuracy= 0.33333
# Step 22800, Minibatch Loss= 1.629813, Training Accuracy= 0.33333
# Step 23400, Minibatch Loss= 1.603624, Training Accuracy= 0.40000
# Step 24000, Minibatch Loss= 1.590120, Training Accuracy= 0.40000
# Step 24600, Minibatch Loss= 1.575034, Training Accuracy= 0.40000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c3f8eaa50b6e> in <module>()
#     134         sess.run(optimizer, feed_dict={source_inputs: batch_source_input,
#     135                                        target_inputs: batch_target_input,
# --> 136                                        target_outputs: batch_target_output})
#     137
#     138         if step % display_step == 0 or step == 1:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
