# %%
# -*- coding: utf-8 -*-
import numpy as np
import tensorflow as tf

# %%
TOKEN_PAD="<p>"
TOKEN_START="<s>"
TOKEN_END="</s>"

source_sentences = ["취미가 뭐예요", "만나서 반가워요", "내일 만나서 놀아요"]
target_sentences = ["what is your hobby", "nice to meet you", "meet tomorrow"]

source_vocab = [TOKEN_PAD, TOKEN_START, TOKEN_END, "취미가", "뭐예요", "만나서", "반가워요", "내일", "놀아요"]
target_vocab = [TOKEN_PAD, TOKEN_START, TOKEN_END, "what", "is", "your", "hobby", "nice", "to", "meet", "you", "tomorrow"]

source_input_idx = [
    [3,  4,  0,  0,  0], 
    [5,  6,  0,  0,  0],  
    [7,  5,  8,  0,  0]]
target_input_idx = [
    [1,  3,  4,  5,  6], 
    [1,  7,  8,  9, 10], 
    [1,  9, 11,  0,  0]]
target_output_idx = [
    [3,  4,  5,  6,  2], 
    [7,  8,  9, 10,  2], 
    [9, 11,  2,  0,  0]]

source_vocab_size = len(source_vocab)
target_vocab_size = len(target_vocab)

embedding_size = 12
num_units = 12
num_layer = 2

batch_size = 3
learning_rate = 0.0002

training_steps = 20000
display_step = 100

max_sentence_length = 5
                   
source_inputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='source_inputs')
target_inputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='target_inputs')
target_outputs = tf.placeholder(dtype=tf.int64, shape=(batch_size, max_sentence_length), name='target_outputs')

def build_single_cell(num_units):
    cell = tf.contrib.rnn.BasicLSTMCell(num_units)
    return cell
                   
with tf.variable_scope('encoder'):
    
    initializer = tf.contrib.layers.xavier_initializer()
    embedding_encoder = tf.get_variable(name="embedding_encoder",
                                        shape=[source_vocab_size, embedding_size], 
                                        dtype=tf.float32,
                                        initializer=initializer,
                                        trainable=True)
    
    encoder_embeddding_inputs = tf.nn.embedding_lookup(params=embedding_encoder,
                                                       ids=source_inputs
                                                      )

    encoder_cell_list = [build_single_cell(num_units) for i in range(num_layer)]
    encoder_multi_cell = tf.contrib.rnn.MultiRNNCell(encoder_cell_list)
    
    encoder_outputs, encoder_final_state = tf.nn.dynamic_rnn(cell=encoder_multi_cell,
                                                             inputs=encoder_embeddding_inputs,
                                                             dtype=tf.float32)
    
with tf.variable_scope('decoder'):
    
    initializer = tf.contrib.layers.xavier_initializer()
    embedding_decoder = tf.get_variable(name="embedding_decoder",
                                        shape=[target_vocab_size, embedding_size], 
                                        dtype=tf.float32,
                                        initializer=initializer,
                                        trainable=True)
    
    decoder_embeddding_inputs = tf.nn.embedding_lookup(params=embedding_decoder,
                                                       ids=target_inputs)
    
    
    decoder_cell_list = [build_single_cell(num_units) for i in range(num_layer)]
    decoder_multi_cell = tf.contrib.rnn.MultiRNNCell(decoder_cell_list)
    
    decoder_initial_state = encoder_final_state
    decoder_outputs, decoder_final_state = tf.nn.dynamic_rnn(cell=decoder_multi_cell,
                                                             inputs=decoder_embeddding_inputs,
                                                             initial_state=decoder_initial_state,
                                                             dtype=tf.float32)

    decoder_predict = tf.argmax(decoder_outputs, 2)
    
with tf.variable_scope("optimizer"):
    cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=decoder_outputs,
                                                            labels=target_outputs)
    cost = tf.reduce_mean(cross_entropy)
    
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    optimizer = optimizer.minimize(cost)
    
    correct_pred = tf.equal(tf.argmax(decoder_outputs, 2), target_outputs)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
    
    

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(tf.global_variables_initializer())

    for step in range(1, training_steps + 1):
        batch_source_input = source_input_idx
        batch_target_input = target_input_idx
        batch_target_output = target_output_idx
        
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={source_inputs: batch_source_input, 
                                       target_inputs: batch_target_input,
                                       target_outputs: batch_target_output})
        
        if step % display_step == 0 or step == 1:
            # Calculate batch accuracy & loss
            outputs, acc, loss = sess.run([decoder_predict, accuracy, cost], feed_dict={source_inputs: batch_source_input, 
                                                              target_inputs: batch_target_input,
                                                              target_outputs: batch_target_output})
            
            print("Step " + str(step * batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
            
        if acc >= 1:
            for sentence in outputs:
                sentence = [target_vocab[word_idx] for word_idx in sentence]
                print("           -> ", sentence)
                
            break;

    print("Optimization Finished!")
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={source_inputs: source_input_idx, 
                                                             target_inputs: target_input_idx,
                                                             target_outputs: target_output_idx}))
# Out:
# Step 3, Minibatch Loss= 2.487141, Training Accuracy= 0.13333
# Step 300, Minibatch Loss= 2.431827, Training Accuracy= 0.26667
# Step 600, Minibatch Loss= 2.246484, Training Accuracy= 0.26667
# Step 900, Minibatch Loss= 2.014348, Training Accuracy= 0.26667
# Step 1200, Minibatch Loss= 1.866883, Training Accuracy= 0.40000
# Step 1500, Minibatch Loss= 1.755239, Training Accuracy= 0.33333
# Step 1800, Minibatch Loss= 1.672862, Training Accuracy= 0.40000
# Step 2100, Minibatch Loss= 1.605613, Training Accuracy= 0.40000
# Step 2400, Minibatch Loss= 1.530987, Training Accuracy= 0.53333
# Step 2700, Minibatch Loss= 1.459294, Training Accuracy= 0.60000
# Step 3000, Minibatch Loss= 1.422488, Training Accuracy= 0.60000
# Step 3300, Minibatch Loss= 1.395847, Training Accuracy= 0.60000
# Step 3600, Minibatch Loss= 1.374039, Training Accuracy= 0.66667
# Step 3900, Minibatch Loss= 1.354536, Training Accuracy= 0.73333
# Step 4200, Minibatch Loss= 1.338123, Training Accuracy= 0.73333
# Step 4500, Minibatch Loss= 1.323499, Training Accuracy= 0.73333
# Step 4800, Minibatch Loss= 1.309818, Training Accuracy= 0.73333
# Step 5100, Minibatch Loss= 1.297493, Training Accuracy= 0.80000
# Step 5400, Minibatch Loss= 1.286675, Training Accuracy= 0.80000
# Step 5700, Minibatch Loss= 1.277098, Training Accuracy= 0.80000
# Step 6000, Minibatch Loss= 1.268494, Training Accuracy= 0.80000
# Step 6300, Minibatch Loss= 1.260552, Training Accuracy= 0.80000
# Step 6600, Minibatch Loss= 1.252984, Training Accuracy= 0.80000
# Step 6900, Minibatch Loss= 1.245366, Training Accuracy= 0.80000
# Step 7200, Minibatch Loss= 1.237922, Training Accuracy= 0.80000
# Step 7500, Minibatch Loss= 1.231197, Training Accuracy= 0.80000
# Step 7800, Minibatch Loss= 1.225183, Training Accuracy= 0.80000
# Step 8100, Minibatch Loss= 1.219786, Training Accuracy= 0.80000
# Step 8400, Minibatch Loss= 1.214899, Training Accuracy= 0.80000
# Step 8700, Minibatch Loss= 1.210435, Training Accuracy= 0.80000
# Step 9000, Minibatch Loss= 1.206332, Training Accuracy= 0.80000
# Step 9300, Minibatch Loss= 1.202537, Training Accuracy= 0.80000
# Step 9600, Minibatch Loss= 1.199027, Training Accuracy= 0.80000
# Step 9900, Minibatch Loss= 1.195819, Training Accuracy= 0.80000
# Step 10200, Minibatch Loss= 1.192890, Training Accuracy= 0.80000
# Step 10500, Minibatch Loss= 1.190204, Training Accuracy= 0.80000
# Step 10800, Minibatch Loss= 1.187733, Training Accuracy= 0.80000
# Step 11100, Minibatch Loss= 1.185453, Training Accuracy= 0.80000
# Step 11400, Minibatch Loss= 1.183343, Training Accuracy= 0.80000
# Step 11700, Minibatch Loss= 1.181384, Training Accuracy= 0.80000
# Step 12000, Minibatch Loss= 1.179559, Training Accuracy= 0.80000
# Step 12300, Minibatch Loss= 1.177852, Training Accuracy= 0.80000
# Step 12600, Minibatch Loss= 1.176251, Training Accuracy= 0.80000
# Step 12900, Minibatch Loss= 1.174743, Training Accuracy= 0.80000
# Step 13200, Minibatch Loss= 1.173319, Training Accuracy= 0.80000
# Step 13500, Minibatch Loss= 1.171972, Training Accuracy= 0.80000
# Step 13800, Minibatch Loss= 1.170697, Training Accuracy= 0.80000
# Step 14100, Minibatch Loss= 1.169488, Training Accuracy= 0.80000
# Step 14400, Minibatch Loss= 1.168339, Training Accuracy= 0.80000
# Step 14700, Minibatch Loss= 1.167244, Training Accuracy= 0.80000
# Step 15000, Minibatch Loss= 1.166197, Training Accuracy= 0.80000
# Step 15300, Minibatch Loss= 1.165188, Training Accuracy= 0.80000
# Step 15600, Minibatch Loss= 1.164209, Training Accuracy= 0.80000
# Step 15900, Minibatch Loss= 1.163250, Training Accuracy= 0.80000
# Step 16200, Minibatch Loss= 1.162285, Training Accuracy= 0.80000
# Step 16500, Minibatch Loss= 1.161211, Training Accuracy= 0.80000
# Step 16800, Minibatch Loss= 1.155378, Training Accuracy= 0.86667
# Step 17100, Minibatch Loss= 1.146479, Training Accuracy= 0.86667
# Step 17400, Minibatch Loss= 1.144724, Training Accuracy= 0.86667
# Step 17700, Minibatch Loss= 1.143368, Training Accuracy= 0.86667
# Step 18000, Minibatch Loss= 1.141576, Training Accuracy= 0.93333
# Step 18300, Minibatch Loss= 1.137831, Training Accuracy= 1.00000
#            ->  ['what', 'is', 'your', 'hobby', '</s>']
#            ->  ['nice', 'to', 'meet', 'you', '</s>']
#            ->  ['meet', 'tomorrow', '</s>', '<p>', '<p>']
# Optimization Finished!
# Testing Accuracy: 1.0
